# %%
import os
import re

os.chdir(r'/home/naiph/Downloads')

# List all files in directory and filter those that aren't txt files
files = os.listdir(os.getcwd())
txt_files = []

txt_regex = re.compile(r'.xlrs')

for i in files:
    if txt_regex.search(i) is not None:
        txt_files.append(i)

# %%
import xlrd, os
os.chdir('/home/naiph/Downloads/')

workbook = xlrd.open_workbook('Reupload Assignment 5 (4) - Neelima B.xlsx')

# %%
sheet = workbook.sheet_by_index(0) 
print(sheet.cell_value(3,0)) # name
print(sheet.cell_value(7,21)) # 1st time
print(sheet.cell_value(11,20)) # 1st score

print(sheet.cell_value(14,21)) # 2nd time 
print(sheet.cell_value(18,20)) # 2nd score

print(sheet.cell_value(20,21)) # 3rd time
print(sheet.cell_value(23,20)) # 3rd score

print(sheet.cell_value(26,21)) # 4th time 
print(sheet.cell_value(28,20)) # 4th score
# Out:
# Name : P.L.Alekhyaname
# 96.0
# 10.0
# 131.0
# 9.0
# 117.0
# 10.0
# 110.0
# 10.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.chdir('/home/naiph/Downloads/')
df = pd.read_excel('Reupload Assignment 5 (4) - Neelima B.xlsx')

# %%
df
# Out:
#             Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                  NaN         NaN         NaN         NaN         NaN
# 1    Date : 10.07.2020         NaN         NaN         NaN         NaN
# 2   Name : P.L.Alekhya         NaN         NaN         NaN         NaN
# 3                  NaN         NaN         NaN         NaN         NaN
# 4                    1         NaN         2.0         NaN         3.0
# 5                  NaN         8.0         NaN         2.0         NaN
# 6                  NaN         8.0         NaN         8.0         NaN
# 7                  NaN         8.0         NaN         7.0         NaN
# 8                  NaN         3.0         NaN         4.0         NaN
# 9                  NaN        27.0         NaN        21.0         NaN
# 10                 NaN         1.0         NaN         1.0         NaN
# 11                   1         NaN         2.0         NaN         3.0
# ...
