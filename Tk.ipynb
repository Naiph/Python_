# %%
from tkinter import *
from tkinter import messagebox

window = Tk()
window.title('Parking lot system')
window.geometry('1000x500') # size of window


lbl = Label(window, text = 'Select your lot', font = ('Arial Bold', 20)) # creating a label
lbl.grid(row=0, column=0) # label wont show up without this
    
    
def clicked1():
    btn1.configure(bg = 'red', text = 'Selected')

def clicked2():
    btn2.configure(bg = 'red', text = 'Selected')

def clicked3():
    btn3.configure(bg = 'red', text = 'Selected')

def clicked4():
    btn4.configure(bg = 'red', text = 'Selected')

def clicked5():
    btn5.configure(bg = 'red', text = 'Selected')

def clicked6():
    btn6.configure(bg = 'red', text = 'Selected')

def clicked7():
    btn7.configure(bg = 'red', text = 'Selected')

def clicked8():
    btn8.configure(bg = 'red', text = 'Selected')


    
btn1 =  Button(window, text = 'Park here', bg = 'green', command = clicked1)
btn1.grid(column = 1, row = 1)

btn2 =  Button(window, text = 'Park here', bg = 'green', command = clicked2)
btn2.grid(column = 2, row = 1)

btn3 =  Button(window, text = 'Park here', bg = 'green', command = clicked3)
btn3.grid(column = 3, row = 1)

btn4 =  Button(window, text = 'Park here', bg = 'green', command = clicked4)
btn4.grid(column = 4, row = 1)

btn5 =  Button(window, text = 'Park here', bg = 'green', command = clicked5)
btn5.grid(column = 1, row = 2)

btn6 =  Button(window, text = 'Park here', bg = 'green', command = clicked6)
btn6.grid(column = 2, row = 2)

btn7 =  Button(window, text = 'Park here', bg = 'green', command = clicked7)
btn7.grid(column = 3, row = 2)

btn8 =  Button(window, text = 'Park here', bg = 'green', command = clicked8)
btn8.grid(column = 4, row = 2)

# ---------


name = Label(window, text = 'Enter your Name').grid(column = 0,row=2)
txt1 = Entry(window, width = 10)
txt1.grid(column = 0, row = 3)
txt1.focus() # text cursor will be here at the beginning
#n = (txt1.get())

time = Label(window, text = 'How long will you be parking for?').grid(column = 0, row = 4)
txt2 = Entry(window, width = 10).grid(column = 0, row = 5)
#t = (txt2.get())

phone = Label(window, text= 'Enter your phone no.').grid(column=0, row=6)
txt3 = Entry(window, width = 10).grid(column=0, row=7)
#p = (txt3.get())

def mesbox():
    messagebox.showinfo(title = 'Thanks', message = 'Your slot has been booked')
    
btn = Button(window, text = 'Submit', command = mesbox)
btn.grid(row = 8, column=1)

window.mainloop() # nothing will appear if we do not call this
